# %%
import matplotlib.pyplot as plt
import numba as nb
import numpy as np
import sombrero

# %% [markdown]
# $F=0.18$ $N=50$

# %% [markdown]
# $x_0=-0.9$ $y_0=0$

# %%
vals = sombrero.sombrero(0.18, -0.9, 0, 50)
sombrero.line(vals, 0.18, "$F=0.18$, $x_0=-0.9$, $y_0=0$, $N=50$")
sombrero.scatter(vals, 0.18, "$F=0.18$, $x_0=-0.9$, $y_0=0$, $N=50$")

# %% [markdown]
# $x_0=0.9$ $y_0=0$

# %%
vals2 = sombrero.sombrero(0.18, 0.9, 0, 50)
sombrero.line(vals2, 0.18, "$F=0.18$, $x_0=0.9$, $y_0=0$, $N=50$")
sombrero.scatter(vals2, 0.18, "$F=0.18$, $x_0=0.9$, $y_0=0$, $N=50$")

# %% [markdown]
# $F=0.25$ $N=50$

# %% [markdown]
# $x_0=0.2$ $y_0=0.1$

# %%
vals3 = sombrero.sombrero(0.25, 0.2, 0.1, 50)
sombrero.line(vals3, 0.25, "$F=0.25$, $x_0=0.2$, $y_0=0.1$, $N=50$")
sombrero.scatter(vals2, 0.25, "$F=0.25$, $x_0=0.2$, $y_0=0.1$, $N=50$")

# %% [markdown]
# $x_0=0.201$ $y_0=0.1$

# %%
vals4 = sombrero.sombrero(0.25, 0.201, 0.1, 50)
sombrero.line(vals4, 0.25, "$F=0.25$, $x_0=0.201$, $y_0=0.1$, $N=50$")
sombrero.scatter(vals4, 0.25, "$F=0.25$, $x_0=0.201$, $y_0=0.1$, $N=50$")

# %% [markdown]
# $F=0.4$ $N=50$

# %% [markdown]
# $x_0=0$ $y_0=0$

# %%
vals5 = sombrero.sombrero(0.4, 0, 0, 50)
sombrero.line(vals5, 0.4, "$F=0.4$, $x_0=0$, $y_0=0$, $N=50$")
sombrero.scatter(vals5, 0.4, "$F=0.4$, $x_0=0$, $y_0=0$, $N=50$")

# %% [markdown]
# $F=0.4$ $N=1000$

# %%
vals6 = sombrero.sombrero(0.4, 0, 0, 1000)
sombrero.line(vals6, 0.4, "$F=0.4$, $x_0=0$, $y_0=0$, $N=1000$")
sombrero.scatter(vals6, 0.4, "$F=0.4$, $x_0=0$, $y_0=0$, $N=1000$")
